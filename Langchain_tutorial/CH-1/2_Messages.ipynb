# %% [markdown]
# # **Messages**

# %%
import os
from dotenv import load_dotenv


# This function will load all the variable from .env file and will
# will make available in os.eviron dictionary (env variables)
load_dotenv()

if os.environ.get("GEMINI_API_KEY"):
    print("API key variable exist")
else:
    print("GEMINI_API_KEY not found")
# Out:
# API key variable exist

# %%
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_google_genai import ChatGoogleGenerativeAI

llm_gemini = ChatGoogleGenerativeAI(
    model = "gemini-3-flash-preview",
    google_api_key = os.getenv("GEMINI_API_KEY"),
    temperature = 0
)

my_message = [
    SystemMessage(content= "You are a gen-z assistant who always answers in a fun way"),
    HumanMessage(content= "Bro, tell me a fun fact")
]

llm_gemini.invoke(my_message).text
# Out:
# 'Yo, I gotchu! 💅✨\n\nDid you know that **wombats actually poop in cubes**? 🧊💩 \n\nNo cap, they’re the only animals in the world that do this. They use their square business to mark their territory, and the shape keeps it from rolling away. They’re literally out here playing Minecraft in real life. 💀\n\nStay iconic, bestie! ✌️🔥'

# %% [markdown]
# # **Prompts**
#
# Prompts are the messages that are sent to the LLM. Prompts are more user-freindly than messages.

# %%
from langchain_core.prompts import PromptTemplate


user_input = input("Enter Topic for fun fact : ")

dynamic_promt = PromptTemplate.from_template("write fun fact about {topic}")

ready_prompt = dynamic_promt.invoke({"topic": user_input})

llm_gemini.invoke(ready_prompt).text
# Out:
# 'Here are some of the most fascinating and fun facts about flowers:\n\n*   **Sunflowers are math geniuses:** The seeds in the center of a sunflower follow the **Fibonacci sequence** (1, 2, 3, 5, 8, 13, 21, etc.). This mathematical pattern allows the flower to pack the maximum number of seeds into the smallest possible space.\n*   **Roses are related to your favorite snacks:** Roses belong to the *Rosaceae* family, which means they are closely related to **apples, peaches, cherries, pears, and even almonds.**\n*   **The "Corpse Flower" is the world’s smelliest:** The *Titan Arum* is the largest unbranched flower in the world, reaching up to 10 feet tall. However, you wouldn\'t want it in a bouquet—it smells like **rotting meat** to attract flies and beetles for pollination.\n*   **Tulips were once worth more than gold:** In the 1600s in the Netherlands, tulip bulbs were so highly valued that they triggered "Tulip Mania." At the height of the bubble, a single bulb could cost more than 
# ...

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt_template = ChatPromptTemplate.from_messages([
    ("system", "You are {tone} assistant"),
    ("user", "Write fun fact about {topic}")
])

user_input = input("Enter the topic : ")
user_tone = input("Enter a tone: ")
ready_prompt = prompt_template.invoke({"topic": user_input,"tone":user_tone})

llm_gemini.invoke(ready_prompt).text
# Out:
# 'Hello! I would be delighted to share a fun fact about artificial intelligence with you.\n\nDid you know that **AI is currently being used to help humans "talk" to animals?**\n\nScientists are using advanced machine learning models to analyze the complex clicks of sperm whales and the "waggle dances" of honeybees. By processing thousands of hours of these sounds and movements, researchers hope to decode their communication patterns. The goal is to eventually use AI to translate these signals, potentially allowing us to understand what animals are saying to one another!\n\nIt is truly fascinating how technology is helping us bridge the gap between humans and the natural world. I hope you found that interesting!'
